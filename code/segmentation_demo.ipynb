# %% [markdown]
# **Validation Image**

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time


# loading images and resizing
test_image_dir = '/content/drive/MyDrive/splitted datanew/splitted data/validation/images_bleed'
image_path = os.path.join(test_image_dir, 'img- (1256).png')
img1 = plt.imread(image_path)
image = cv2.imread(image_path) / 255.0
target_size = (224, 224)
resized_image = cv2.resize(image, target_size)
test_image = np.array([resized_image])

#prediction
predicted_mask = model.predict(test_image)

# plotting images
plt.figure(figsize=(15, 5))
original_image = img1
plt.subplot(1, 3, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis('off')


predicted_mask = (predicted_mask.squeeze() * 255).astype(np.uint8)
predicted_mask_resized = cv2.resize(predicted_mask, (original_image.shape[1], original_image.shape[0]))
predicted_mask_resized_3channels = cv2.merge([predicted_mask_resized] * 3)
plt.subplot(1, 3, 2)
plt.imshow(predicted_mask_resized_3channels, cmap='gray')
plt.title("Predicted Mask")
plt.axis('off')

# Overlay predicted mask on original image
overlay = cv2.addWeighted((original_image * 255).astype(np.uint8), 0.7, predicted_mask_resized_3channels, 0.3, 0)
threshold = 0.5
binary_mask = (predicted_mask > threshold).astype(np.uint8)
contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# bounding box drawing
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    confidence = np.mean(predicted_mask[y:y+h, x:x+w])
    c=confidence/255
    cv2.rectangle(overlay, (x, y), (x + w, y + h), (0, 255, 0), 2)
    text = f'{c:.2f}'
    cv2.putText(overlay, text, (x, y +100), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

plt.subplot(1, 3, 3)
plt.imshow(overlay)
plt.title("Overlay")
plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step

# %% [markdown]
# **Testdata1**

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time


# loading images and resizing
test_image_dir = '/content/drive/MyDrive/testdata1'
image_path = os.path.join(test_image_dir, 'A0038.png')
image = cv2.imread(image_path) / 255.0
target_size = (224, 224)
resized_image = cv2.resize(image, target_size)
test_image = np.array([resized_image])

#prediction
predicted_mask = model.predict(test_image)

# plotting images
plt.figure(figsize=(15, 5))


original_image = img1
plt.subplot(1, 3, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis('off')

predicted_mask = (predicted_mask.squeeze() * 255).astype(np.uint8)
predicted_mask_resized = cv2.resize(predicted_mask, (original_image.shape[1], original_image.shape[0]))
predicted_mask_resized_3channels = cv2.merge([predicted_mask_resized] * 3)
plt.subplot(1, 3, 2)
plt.imshow(predicted_mask_resized_3channels, cmap='gray')
plt.title("Predicted Mask")
plt.axis('off')

# Overlay predicted mask on original image
overlay = cv2.addWeighted((original_image * 255).astype(np.uint8), 0.7, predicted_mask_resized_3channels, 0.3, 0)
#contour finding
threshold = 0.5
binary_mask = (predicted_mask > threshold).astype(np.uint8)
contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# bounding box drawing
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    confidence = np.mean(predicted_mask[y:y+h, x:x+w])
    c=confidence/255
    cv2.rectangle(overlay, (x, y), (x + w, y + h), (0, 255, 0), 2)
    text = f'{c:.2f}'
    cv2.putText(overlay, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

plt.subplot(1, 3, 3)
plt.imshow(overlay)
plt.title("Overlay")
plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 128ms/step

# %% [markdown]
# **Testdata2**

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time


# loading images and resizing
test_image_dir = '/content/drive/MyDrive/testdata2'
image_path = os.path.join(test_image_dir, 'A0299.png')
img1 = plt.imread(image_path)
image = cv2.imread(image_path) / 255.0
target_size = (224, 224)
resized_image = cv2.resize(image, target_size)
test_image = np.array([resized_image])

#prediction
predicted_mask = model.predict(test_image)

# plotting images
plt.figure(figsize=(15, 5))
original_image = img1
plt.subplot(1, 3, 1)
plt.imshow(original_image)
plt.title("Original Image")
plt.axis('off')


predicted_mask = (predicted_mask.squeeze() * 255).astype(np.uint8)
predicted_mask_resized = cv2.resize(predicted_mask, (original_image.shape[1], original_image.shape[0]))
predicted_mask_resized_3channels = cv2.merge([predicted_mask_resized] * 3)
plt.subplot(1, 3, 2)
plt.imshow(predicted_mask_resized_3channels, cmap='gray')
plt.title("Predicted Mask")
plt.axis('off')

# Overlay predicted mask on original image
overlay = cv2.addWeighted((original_image * 255).astype(np.uint8), 0.7, predicted_mask_resized_3channels, 0.3, 0)

threshold = 0.5
binary_mask = (predicted_mask > threshold).astype(np.uint8)
contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# bounding box drawing
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    confidence = np.mean(predicted_mask[y:y+h, x:x+w])
    c=confidence/255
    cv2.rectangle(overlay, (x, y), (x + w, y + h), (0, 255, 0), 2)
    text = f'{c:.2f}'
    cv2.putText(overlay, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

plt.subplot(1, 3, 3)
plt.imshow(overlay)
plt.title("Overlay")
plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
